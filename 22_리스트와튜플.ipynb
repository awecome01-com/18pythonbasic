# %%
#리스트에 요소 하나 추가하기
a = [10,20,30]
a.append(500)
a
# Out:
# [10, 20, 30, 500]

# %%
#리스트 안에 리스트 추가하기
a = [10,20,30]
a.append([500,600])
print(a)
# Out:
# [10, 20, 30, [500, 600]]

# %%
#리스트의 특정 인덱스에 요소 추가하기
a = [10,20,30]
a.insert(0,500)
a
# Out:
# [500, 10, 20, 30]

# %%
a=[10,20,30]
a.insert(1,[500,600])
a
# Out:
# [10, [500, 600], 20, 30]

# %%
a=[10,20,30]
a[1:1]=[500,600]
a
# Out:
# [10, 500, 600, 20, 30]

# %%
test=[
    [1,3,5,7,9],
    ["a","b","c","d","e"],
    ["1","2","3","4","5"]
]

# %%
#리스트에서 특정 값의 인덱스 구하기
a = [10,20,30,15,20,40]
a.index(20)
# Out:
# 1

# %%
#특정 값의 개수 구하기
a = [10,20,30,15,20,40]
a.count(20)
# Out:
# 2

# %%
#리스트의 순서를 뒤집기
a = [10,20,30,15,20,40]
# list(reversed(a))
a.reverse
print(a)
# Out:
# [10, 20, 30, 15, 20, 40]
