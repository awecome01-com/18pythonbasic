# %%
#문자열 사용
hello = "Hello world"
hello
# Out:
# 'Hello world'

# %%
hello='안녕하세요'
hello
# Out:
# '안녕하세요'

# %%
'''Hello python'''
hello
# Out:
# '안녕하세요'

# %%
python="""python programming"""
python
# Out:
# 'python programming'

# %%
#여러줄로 된 문자열 사용하기
'''hello world
안녕하세요
python입니다'''
# Out:
# 'hello world\n안녕하세요\npython입니다'

# %%
#문자열 안에 작은따옴표나 큰따옴표 포함하기
s= "python isn's difficult"
print(s)
# Out:
# python isn's difficult
