# %%
#빈 딕셔너리 만들기
딕셔너리 = []
딕셔너리 = dict()

# dict로 딕셔너리 만들기
lux1 = dict()

iter1 = ["health", "mana", "melee", "armor"]
iter2 = [490, 334, 550, 18.72]
list(zip)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       6 lux1 = dict()
#       7
#       8 iter1 = ["health", "mana", "melee", "armor"]
#       9 iter2 = [490, 334, 550, 18.72]
# ---> 10 list(zip)
#
# TypeError: 'type' object is not iterable

# %%
lux["armor"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 lux["armor"]
#
# NameError: name 'lux' is not defined

# %%
#딕셔너리의 값 할당하기
lux["mana_regan"]= 3.28
lux
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #딕셔너리의 값 할당하기
# ----> 2 lux["mana_regan"]= 3.28
#       3 lux
#
# NameError: name 'lux' is not defined

# %%
#딕셔너리의 키 개수 구하기
lux = ('health':490,'mana': 334, 'melee':550, 'ar"manamor':18,72)
len(lux)
# Out:
#   Cell In[5], line 2
#     lux = ('health':490,'mana': 334, 'melee':550, 'ar"manamor':18,72)
#                    ^
# SyntaxError: invalid syntax
