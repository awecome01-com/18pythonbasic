# %%
#조건문에 숫자 지정하기

if 0:
    print("참")
else:
    print("거짓")

if 1 :
    print("참")
else:
    print("거짓")

if 0x1f:
    print("참")
else:
    print("거짓")

# %%
#if조건문에 문자열 지정하기
if "hello":
    print()

# %%
국어,영어,수학,과학 = list(map(int, input().split()))
if 0<= 국어<= 100 and 0 <= 영어 <= 100 and 0 <= 수학 <=100 and 0 <=과학 <=100:
    avg =(국어+영어+수학+과학)/4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 국어,영어,수학,과학 = list(map(int, input().split()))
#       2 if 0<= 국어<= 100 and 0 <= 영어 <= 100 and 0 <= 수학 <=100 and 0 <=과학 <=100:
#       3     avg =(국어+영어+수학+과학)/4
#       4
#
# ValueError: not enough values to unpack (expected 4, got 1)
