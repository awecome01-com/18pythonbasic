# %%
#리스트 만들기
a=(38,21,53,62,19)
print(a)
# Out:
# (38, 21, 53, 62, 19)

# %%
person=(
    "james",
    17,
    175.3,
    True
)

# %%
#빈 리스트 만들기
a=[]
b=list()
int()
float()
# Out:
# 0.0

# %%
#range를 사용하여 리스트 만들기
range(10)
# Out:
# range(0, 10)

# %%
list(range(5,12))
# Out:
# [5, 6, 7, 8, 9, 10, 11]

# %%
list(range(10,0,-1_)
# Out:
#   Cell In[8], line 1
#     list(range(10,0,-1_)
#                       ^
# SyntaxError: invalid decimal literal

# %%
#튜플사용하기
a=[38,21,53,62,19]
b=38,21,53,62,19
print(a)
print(b)
# Out:
# [38, 21, 53, 62, 19]
# (38, 21, 53, 62, 19)

# %%
a=[1]
b=(1,)
c=(1)

# %%
#요소가 한 개 들어있는 튜플만들기
(38)
# Out:
# 38

# %%
# range를 사용하여 튜플만들기
range(10)
# Out:
# range(0, 10)

# %%
#튜플을 리스트로 만들고 리스트를 튜플로 만들기
a=(1,2,3)
a= triple(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 #튜플을 리스트로 만들고 리스트를 튜플로 만들기
#       2 a=(1,2,3)
# ----> 3 a= triple(s)
#
# NameError: name 'triple' is not defined

# %%
b= (4,5,6)

# %%
list(b)
# Out:
# [4, 5, 6]

# %%
number = int(input())
tuple(range(-10,10,number))
# Out:
# (-10, 0)
