# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
#비교연산자
3>1
# Out:
# True

# %%
#숫자가 같은지 다른지 비교
print(10 == 10)
# Out:
# True

# %%
print(10 != 5)
# Out:
# True

# %%
print (python == "Python")
print (python == "python")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print (python == "Python")
#       2 print (python == "python")
#
# NameError: name 'python' is not defined

# %%
#부등호 사용하기
print(10 > 20)
print(10 >= 20)
# Out:
# False
# False

# %%
print(1==1.0)
# Out:
# True

# %%
print(1 is 1.0)
print(id(1))
# Out:
# False
# 140720798855976
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_17376\2017046431.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   print(1 is 1.0)

# %%
#논리연산자 사용하기
print(True and True and True)
print(True and False and True)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
not True
# Out:
# False

# %%
not True and False or not False
False and False or True
False or True
# Out:
# True

# %%
#논리연산자와 비교연산자 함께 사용하기
print(10==10 and 10 !=5)
print(10>5 or 10<3 )
print(not 10>5)
# Out:
# True
# True
# False

# %%
False > 5
# Out:
# False

# %%
print(not 1 is 1.0)
# Out:
# True
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_17376\4055061545.py:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   print(not 1 is 1.0)
